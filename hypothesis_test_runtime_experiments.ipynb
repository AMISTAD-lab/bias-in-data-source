# %%
# Data preprocessing

import csv
import pandas as pd
from hypothesis_test import *
from kardis_test import *
from mg_calculator import *
from q_finder import *
from graph_distributions import *
from random import choices

df = pd.read_csv(r'Datasets/compas-scores-two-years.csv')
df = df[(df['days_b_screening_arrest'] >= -30) & (df['days_b_screening_arrest'] <= 30)]
df = df[df['is_recid'] != -1]
df = df[df['c_charge_degree'] != 'O']
df = df[df['score_text'] != 'N/A']
df
# Out:
#          id                 name      first       last compas_screening_date  \
# 0         1     miguel hernandez     miguel  hernandez            2013-08-14
# 1         3          kevon dixon      kevon      dixon            2013-01-27
# 2         4             ed philo         ed      philo            2013-04-14
# 5         7         marsha miles     marsha      miles            2013-11-30
# 6         8        edward riddle     edward     riddle            2014-02-19
# ...     ...                  ...        ...        ...                   ...
# 7209  10996        steven butler     steven     butler            2013-11-23
# 7210  10997      malcolm simmons    malcolm    simmons            2014-02-01
# 7211  10999      winston gregory    winston    gregory            2014-01-14
# 7212  11000          farrah jean     farrah       jean            2014-03-09
# 7213  11001  florencia sanmartin  florencia  sanmartin            2014-06-30
#
# ...

# %%
white_decile_scores = df[df['race'] == 'Caucasian']['decile_score'].tolist()
AA_decile_scores = df[df['race'] == 'African-American']['decile_score'].tolist()
print(len(AA_decile_scores))
AA_decile_score_props = [AA_decile_scores.count(i)/len(AA_decile_scores) for i in range(1,11)]
possible_scores = list(range(1,11))
extrapolated_AA_scores = list(choices(possible_scores, AA_decile_score_props, k=100000))
from collections import Counter
Counter(extrapolated_AA_scores)
# Out:
# 3175
# Counter({4: 10748,
#          2: 10998,
#          9: 10081,
#          8: 9371,
#          1: 11394,
#          5: 10288,
#          3: 9247,
#          6: 9908,
#          7: 10848,
#          10: 7117})

# %%
def group_decile_scores(score_list, num_groups):
    bound_increment = 10/num_groups
    group_list = []
    last_lower_bound = 0
    for i in range(num_groups):
        upper_bound = last_lower_bound + bound_increment
        group_list.append([last_lower_bound, upper_bound])
        last_lower_bound = upper_bound
    grouped_score_list = []
    for score in score_list:
        for group in group_list:
            if group[0] <= score and score <= group[1]:
                grouped_score_list.append(group_list.index(group))
                break
    return grouped_score_list

def generate_null_hypothesis(score_list, num_groups)
    bound_increment = 10/num_groups
    group_list = []
    last_lower_bound = 0
    for i in range(num_groups):
        upper_bound = last_lower_bound + bound_increment
        group_list.append([last_lower_bound, upper_bound])
        last_lower_bound = upper_bound
    grouped_score_counts = []
    for score in score_list:
        for group in group_list:
            if group[0] <= score and score <= group[1]:
                
                break
# Out:
# [[0, 3.3333333333333335], [3.3333333333333335, 6.666666666666667], [6.666666666666667, 10.0]]
# [0, 0, 0, 1, 1, 1, 2, 2, 2, 2]
