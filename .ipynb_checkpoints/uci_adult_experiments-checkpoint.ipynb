# %%
import pandas as pd
from hypothesis_test import *
from kardis_test import *
from mg_calculator import *
from q_finder import *
from graph_distributions import *

# %%
# Data preprocessing
df = pd.read_csv(r'Datasets/adult.csv', sep=' *, *', na_values='?')
df.shape
# Out:
# (48842, 15)

# %%
# Setup and Experiments
female_income = df[df['sex'] == 'Female']['income'].tolist()
male_income = df[df['sex'] == 'Male']['income'].tolist()
value_list = ['<=50K', '>50K']
hypothesis = [male_income.count(i)/len(male_income) for i in value_list]
alpha = 0.05

print("Null hypothesis (proposed distribution): " + str(hypothesis) + "\n")
q = hypothesis_test(female_income, value_list, alpha, hypothesis)[4]
graph_distributions(q, value_list, hypothesis=hypothesis, xl=['$\leq50$K', '$>50$K'],\
                    filename=r"Results/uci_adult_female_dists.pdf")
# Out:
# Null hypothesis (proposed distribution): [0.6962327718223583, 0.3037672281776417]
#
# Proposed distribution rejected at alpha = 0.05. Kardis = 2.4728089850108e-755.
# Any plausible distribution must boost probability over the given distribution by 2.02199200597703e+753, and will therefore have a minimum probability of 4.72634661744442e-7.
# Closest plausible distribution: [0.8794847422932057, 0.12051525770679433]
